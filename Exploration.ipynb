# %%
import pandas as pd

# %%
data_folder = 'data/'

# %%
df_meta = pd.read_csv(data_folder + 'metadata_complet_with_abstract.csv')

# %%
df_meta.shape
# Out:
# (37576, 18)

# %%
df_meta['language'].unique()
# Out:
# array(['en', 'de', 'zh', 'ja', 'es', 'fr', 'pt', 'it'], dtype=object)

# %%
df_meta[df_meta['language'] == 'it']
# Out:
#        cord_uid                                       sha  source_x  \
# 33565  6bxtgdrb  5bea1407f7c18ef88f4d7ac325d6a7af6960f71d  Elsevier
# 33566  tmhguzsx  292a8103ca5e6b3e674b5074745edbd4e31890e0  Elsevier
# 33567  z498d52g  598ce9971147cad544a81272a7b1eaee18630aee  Elsevier
# 33568  s75d1hat  22019b96ff26f1dcc6b097929522c2b2bf774489  Elsevier
# 33614  jngjogrh  67de735e7e3f2e60bfd376d42819b00faa8bd95e  Elsevier
# 33615  cs415ko7  cadffc6860b51e0b7668940b97cc1a55b1b698df  Elsevier
# 33616  2ievbgw9  7f4c1882faffdb670bec255243cbc5f6025e53b2  Elsevier
# 33617  imrjlhia  c5d8d4101b07277733472f38696c260ccc1a1339  Elsevier
# 34736  tv324cx1  d01e72d035893cf55b445223a4201a5429483d48  Elsevier
# 34737  lpyhdg2m  b2c50a513ae0aceef3856cae3d5c42a0920e9fd5  Elsevier
# 34742  jlhesilu  cc4cc4bb6f0a62dd8d431286fd6a73823b8c82d7  Elsevier
# 34744  st3zdlsc  9d34003fbf306f855cde124b27d012792cd18ffb  Elsevier
#
#                                                    title  \
# ...

# %%
df_meta.set_index('publish_time').loc['2020']
# Out:
#                                                             sha source_x  \
# publish_time
# 2020                   00e5a723d44eb9f2698c38b518eff85c00f9753b      CZI
# 2020                   0938d2fb07611897abf38cea727ddbeea77b73d9      CZI
# 2020                   09c84b9de7fc5c3fed4736e7a3cd45e112377042      CZI
# 2020                   09de57e5401565a1e80361d32b09ce66b3a988c8      CZI
# 2020                   0f5842185d3392825e5ab3768ecb832fb25a3b25      CZI
# ...                                                         ...      ...
# 2020                   53eccda7977a31e3d0f565c884da036b1e85438e      CZI
# 2020          3e5edc4ff36064478e209800a15365cd5f710756; 83a4...      CZI
# 2020          4e550e034ccca6fa2a91e481ddba24db67bc9ae5; 09e2...      CZI
# 2020                   059d5acb8af8bd2bedab06b5dcc0510691fe0f1e      CZI
# 2020          4ecbacf61daab591e76f7471eb6e7fc1a4e0ed70; b31a...      CZI
#
#                                                           title  \
# ...

# %%
pd.read_json(data_folder + 'custom_license/custom_license/aecbc613ebdab36753235197ffb4f35734b5ca63.json', 'records')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2e82d481b944> in <module>
# ----> 1 pd.read_json(data_folder + 'custom_license/custom_license/aecbc613ebdab36753235197ffb4f35734b5ca63.json', 'records')
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
# ...

# %%
import pandas as pd
import json
import os

# Reading the json as a dict
with open(data_folder + 'custom_license/custom_license/aecbc613ebdab36753235197ffb4f35734b5ca63.json') as json_data:
    data = json.load(json_data)

# %%
data['body_text'][0]
# Out:
# {'text': 'The patient (Fo, ) was a 58 year old mentally retarded white woman, born in a rural area of southwestern Virginia.',
#  'cite_spans': [{'start': 12, 'end': 16, 'text': '(Fo,', 'ref_id': None}],
#  'ref_spans': [],
#  'section': ''}

# %%
data.keys()
# Out:
# dict_keys(['paper_id', 'metadata', 'abstract', 'body_text', 'bib_entries', 'ref_entries', 'back_matter'])

# %%
data
# Out:
# {'paper_id': 'aecbc613ebdab36753235197ffb4f35734b5ca63',
#  'metadata': {'title': 'Clinical and Immunologic Studies in Identical Twins Discordant for Systemic Lupus Erythematosus',
#   'authors': [{'first': 'Carolyn',
#     'middle': ['M'],
#     'last': 'Brunner',
#     'suffix': '',
#     'affiliation': {'laboratory': '',
#      'institution': 'University of Virginia',
#      'location': {'settlement': 'Charlottesville', 'region': 'Virginia'}},
#     'email': ''},
#    {'first': 'A',
#     'middle': [],
#     'last': 'David',
#     'suffix': '',
#     'affiliation': {'laboratory': '',
#      'institution': 'University of Virginia',
#      'location': {'settlement': 'Charlottesville', 'region': 'Virginia'}},
#     'email': ''},
#    {'first': '',
#     'middle': [],
#     'last': 'Horwitz',
#     'suffix': '',
#     'affiliation': {'laboratory': '',
#      'institution': 'University of Virginia',
#      'location': {'settlement': 'Charlottesville', 'region': 'Virginia'}},
# ...

# %%
df = pd.DataFrame.from_dict(data, orient='index').T

# %%
metadata = df.metadata[0]

# %%
metadata['title']
# Out:
# 'Clinical and Immunologic Studies in Identical Twins Discordant for Systemic Lupus Erythematosus'
